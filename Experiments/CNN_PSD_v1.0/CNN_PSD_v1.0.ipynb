# %% [markdown]
# ### MODEL

# %% [markdown]
# ### Use Anaconda Terminal
# # Always run ( conda activate gpu_env ) before all

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.4.1
# True

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
# Out:
# TensorFlow version: 2.3.0
# Built with CUDA: False

# %%
import os
import numpy as np
import pandas as pd
import mne
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# 1. Load Metadata and Map Labels

# %%
metadata = pd.read_csv('Dataset/participants.tsv', sep='\t')
print(metadata.head())

group_mapping = {'A': 0, 'F': 1, 'C': 2}
metadata['label'] = metadata['Group'].map(group_mapping)
print(metadata[['participant_id', 'Group', 'label']].head())

subject_labels = dict(zip(metadata['participant_id'], metadata['label']))
# Out:
#   participant_id Gender  Age Group  MMSE
# 0        sub-001      F   57     A    16
# 1        sub-002      F   78     A    22
# 2        sub-003      M   70     A    14
# 3        sub-004      F   67     A    20
# 4        sub-005      M   70     A    22
#   participant_id Group  label
# 0        sub-001     A      0
# 1        sub-002     A      0
# 2        sub-003     A      0
# 3        sub-004     A      0
# 4        sub-005     A      0

# %% [markdown]
#  succesfully ran the below code
# <p>
# <p>
# <p>0 bad epochs dropped
# <p>Effective window size : 0.512 (s)
# <p>Loading: Dataset\derivatives\sub-088\eeg\sub-088_task-eyesclosed_eeg.set
# <p>Filtering raw data in 1 contiguous segment
# <p>Setting up band-pass filter from 0.5 - 45 Hz
# <p>
# <p>FIR filter parameters
# <p>---------------------
# <p>Designing a one-pass, zero-phase, non-causal bandpass filter:
# <li> Windowed time-domain design (firwin) method
# <li> Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# <li>> Lower passband edge: 0.50
# <li> Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# <li> Upper passband edge: 45.00 Hz
# <li> Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# <li>Filter length: 3301 samples (6.602 sec)
# <p>
# <p>C:\Users\Microsoft\AppData\Local\Temp\ipykernel_23456\489852142.py:50: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and <p>epoching around these events.
# <p>  raw = mne.io.read_raw_eeglab(set_file_path, preload=True)
# <p>Not setting metadata
# <p>783 matching events found
# <p>No baseline correction applied
# <p>0 projection items activated
# <p>Using data from preloaded Raw for 783 events and 1000 original time points ...
# <p>[Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <p>0 bad epochs dropped
# <p>Effective window size : 0.512 (s)
# <p>Final training feature shape: (55764, 19, 5, 1)
# <p>Final test feature shape: (13942, 19, 5, 1)
# <p>Final label vector shape: (69706,)

# %%
import os
import numpy as np
import pandas as pd
import mne
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

metadata = pd.read_csv('Dataset/participants.tsv', sep='\t')
group_mapping = {'A': 0, 'F': 1, 'C': 2}
metadata['label'] = metadata['Group'].map(group_mapping)
subject_labels = dict(zip(metadata['participant_id'], metadata['label']))

# -----------------------------
# 2. Define Paths and Initialize Containers

derivatives_path = os.path.join('Dataset', 'derivatives')
subject_folders = [os.path.join(derivatives_path, d) for d in os.listdir(derivatives_path) if d.startswith('sub-')]

all_features = []
all_epoch_subject_ids = []

freq_bands = {
    "delta": (0.5, 4),
    "theta": (4, 8),
    "alpha": (8, 13),
    "beta": (13, 25),
    "gamma": (25, 45),
}

# -----------------------------
# 3. Loop Over All Subject Folders and Process EEG Data

for subject_folder in subject_folders:
    eeg_folder = os.path.join(subject_folder, 'eeg')
    set_files = [f for f in os.listdir(eeg_folder) if f.endswith('.set')]
    if not set_files:
        continue
    
    set_file_path = os.path.join(eeg_folder, set_files[0])
    print("Loading:", set_file_path)
    
    raw = mne.io.read_raw_eeglab(set_file_path, preload=True)
    raw.filter(0.5, 45, fir_design='firwin')
    
    # Create fixed-length epochs (2 seconds duration, 1 second overlap)
    epochs = mne.make_fixed_length_epochs(raw, duration=2.0, overlap=1, preload=True)
    # Use the events array length since bad epochs may not be dropped:

    psd = epochs.compute_psd(method="welch", fmin=0.5, fmax=45)
    psds, freqs = psd.get_data(return_freqs=True)
    
    band_power = {}
    for band, (fmin, fmax) in freq_bands.items():
        idx = np.logical_and(freqs >= fmin, freqs <= fmax)
        band_power[band] = psds[:, :, idx].mean(axis=-1)
    
    bp_abs = np.stack(list(band_power.values()), axis=-1)
    total_power = bp_abs.sum(axis=-1, keepdims=True)
    rbp_relative = bp_abs / total_power

    features = rbp_relative.reshape(rbp_relative.shape[0],
                                    rbp_relative.shape[1],
                                    rbp_relative.shape[2], 1)
    
    all_features.append(features)
    subject_id = os.path.basename(subject_folder)
    num_epochs = features.shape[0]
    all_epoch_subject_ids.extend([subject_id] * num_epochs)

# Concatenate features across all subjects
X = np.concatenate(all_features, axis=0)
n_channels, n_freqs, n_times = X.shape[1:]
y = np.array([subject_labels[pid] for pid in all_epoch_subject_ids])

# Reshape for scaling: (n_epochs, n_channels, n_freqs, n_times) → (n_epochs, -1)
X_reshaped = X.reshape(X.shape[0], -1)

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Reshape back to original shape
X_train = X_train.reshape(X_train.shape[0], n_channels, n_freqs, n_times)
X_test = X_test.reshape(X_test.shape[0], n_channels, n_freqs, n_times)

print("Final training feature shape:", X_train.shape)
print("Final test feature shape:", X_test.shape)
print("Final label vector shape:", y.shape)

# %%
print(len(all_epoch_subject_ids))  # Should match 69706
# Out:
# 69706

# %%
print("X shape:", X.shape)  # Should be (num_samples, 19, 5, 1)
print("X min/max:", np.min(X), np.max(X))  # Should be properly scaled
print("X mean/std:", np.mean(X), np.std(X))  # Should not be extreme values
# Out:
# X shape: (69706, 19, 5, 1)
# X min/max: 5.687052153233299e-05 0.9968445487234848
# X mean/std: 0.2000000000000001 0.30650708216262385

# %%
print("y dtype:", y.dtype)  # Must be int
# Out:
# y dtype: int32

# %%
import numpy as np
print("Unique labels in y:", np.unique(y))
print("Label counts:", np.bincount(y))
# Out:
# Unique labels in y: [0 1 2]
# Label counts: [29081 16556 24069]

# %%
print("Shape before last Conv2D:", X.shape)
# Out:
# Shape before last Conv2D: (69706, 19, 5, 1)

# %%
# 4. Model Definition 

from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import DepthwiseConv2D, Multiply, Add, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import SpatialDropout2D  # Add to your imports

from tensorflow.keras.layers import (
    Input, Conv2D, DepthwiseConv2D,  # Explicit Conv2D import
    BatchNormalization, MaxPooling2D,
    Flatten, Dense, Dropout, Multiply,
    GlobalAveragePooling2D
)


def create_model(input_shape, nb_classes):
    inputs = Input(shape=input_shape)
    
    # 1. Depthwise Separable Convolution
    x = DepthwiseConv2D((3, 3), depth_multiplier=2, activation='relu', padding='same')(inputs)
    x = Conv2D(32, (1, 1), activation='relu')(x)  # Pointwise convolution
    x = BatchNormalization()(x)
    
    # 2. Frequency-Specific Processing
    x = Conv2D(64, (1, 5), activation='relu', padding='same',  # Kernel spans all channels
               kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)  # Frequency-axis kernel
    
    # 3. Channel Attention (Squeeze-and-Excite Lite)
    squeeze = GlobalAveragePooling2D()(x)
    excitation = Dense(64//4, activation='relu')(squeeze)
    excitation = Dense(64, activation='sigmoid')(excitation)
    x = Multiply()([x, excitation])
    
    # 4. Adaptive Pooling
    x = MaxPooling2D((2, 2))(x)
    x = SpatialDropout2D(0.3)(x)  # Better than Dropout for spatial data
    
    # 5. Frequency Band Consolidation
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    
    # 6. Regularized Classification Head
    x = Flatten()(x)
    x = Dense(64, activation='relu', kernel_constraint=max_norm(3.))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(nb_classes, activation='softmax')(x)
    
    return Model(inputs, outputs)


# 5. Model Training 

# Get input dimensions
input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])  # (channels, freq_bands, 1)
nb_classes = len(np.unique(y))

# Create and compile model
model = create_model(input_shape, nb_classes)

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Class weights for imbalance
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(enumerate(class_weights))

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=7, min_lr=1e-6)
]

# Train model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1
)


# Evaluate on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy: {test_acc:.2%}")
print(f"Test Loss: {test_loss:.4f}")

# Save model
model.save('alzheimer_eeg_model')
# Out:
# Epoch 1/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.9856 - accuracy: 0.5391 - val_loss: 0.8592 - val_accuracy: 0.6262
# Epoch 2/100
# 1743/1743 [==============================] - 10s 6ms/step - loss: 0.8636 - accuracy: 0.6177 - val_loss: 0.7659 - val_accuracy: 0.6657
# Epoch 3/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.7851 - accuracy: 0.6600 - val_loss: 0.6892 - val_accuracy: 0.7168
# Epoch 4/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.7260 - accuracy: 0.6886 - val_loss: 0.6397 - val_accuracy: 0.7348
# Epoch 5/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.6893 - accuracy: 0.7119 - val_loss: 0.6229 - val_accuracy: 0.7485
# Epoch 6/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.6616 - accuracy: 0.7227 - val_loss: 0.5883 - val_accuracy: 0.7652
# Epoch 7/100
# 1743/1743 [==============================] - 17s 10ms/step - loss: 0.6328 - accuracy: 0.7339 - val_loss: 0.5576 - val_accuracy: 0.7721
# Epoch 8/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.6138 - accuracy: 0.7437 - val_loss: 0.5416 - val_accuracy: 0.7885
# Epoch 9/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.5944 - accuracy: 0.7514 - val_loss: 0.5260 - val_accuracy: 0.7916
# Epoch 10/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.5781 - accuracy: 0.7602 - val_loss: 0.5319 - val_accuracy: 0.7804
# Epoch 11/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.5648 - accuracy: 0.7670 - val_loss: 0.5016 - val_accuracy: 0.8036
# Epoch 12/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.5460 - accuracy: 0.7744 - val_loss: 0.4832 - val_accuracy: 0.8135
# Epoch 13/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.5307 - accuracy: 0.7839 - val_loss: 0.4719 - val_accuracy: 0.8189
# Epoch 14/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.5267 - accuracy: 0.7852 - val_loss: 0.4733 - val_accuracy: 0.8184
# Epoch 15/100
# 1743/1743 [==============================] - 10s 6ms/step - loss: 0.5138 - accuracy: 0.7904 - val_loss: 0.4673 - val_accuracy: 0.8178
# Epoch 16/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.5053 - accuracy: 0.7943 - val_loss: 0.4488 - val_accuracy: 0.8299
# Epoch 17/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.5013 - accuracy: 0.7984 - val_loss: 0.4630 - val_accuracy: 0.8202
# Epoch 18/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4940 - accuracy: 0.7999 - val_loss: 0.4557 - val_accuracy: 0.8218
# Epoch 19/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4846 - accuracy: 0.8071 - val_loss: 0.4545 - val_accuracy: 0.8208
# Epoch 20/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4795 - accuracy: 0.8093 - val_loss: 0.4367 - val_accuracy: 0.8365
# Epoch 21/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4728 - accuracy: 0.8094 - val_loss: 0.4483 - val_accuracy: 0.8271
# Epoch 22/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4692 - accuracy: 0.8132 - val_loss: 0.4281 - val_accuracy: 0.8351
# Epoch 23/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4647 - accuracy: 0.8141 - val_loss: 0.4329 - val_accuracy: 0.8334
# Epoch 24/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4603 - accuracy: 0.8162 - val_loss: 0.4303 - val_accuracy: 0.8361
# Epoch 25/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4592 - accuracy: 0.8172 - val_loss: 0.4184 - val_accuracy: 0.8441
# Epoch 26/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4557 - accuracy: 0.8179 - val_loss: 0.4121 - val_accuracy: 0.8434
# Epoch 27/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4548 - accuracy: 0.8197 - val_loss: 0.4204 - val_accuracy: 0.8424
# Epoch 28/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4466 - accuracy: 0.8234 - val_loss: 0.4266 - val_accuracy: 0.8423
# Epoch 29/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4428 - accuracy: 0.8240 - val_loss: 0.4232 - val_accuracy: 0.8339
# Epoch 30/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4401 - accuracy: 0.8259 - val_loss: 0.4061 - val_accuracy: 0.8483
# Epoch 31/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4414 - accuracy: 0.8259 - val_loss: 0.4177 - val_accuracy: 0.8458
# Epoch 32/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4368 - accuracy: 0.8265 - val_loss: 0.4353 - val_accuracy: 0.8334
# Epoch 33/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4340 - accuracy: 0.8287 - val_loss: 0.4100 - val_accuracy: 0.8474
# Epoch 34/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4353 - accuracy: 0.8282 - val_loss: 0.4276 - val_accuracy: 0.8363
# Epoch 35/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4299 - accuracy: 0.8297 - val_loss: 0.4126 - val_accuracy: 0.8434
# Epoch 36/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4274 - accuracy: 0.8323 - val_loss: 0.4174 - val_accuracy: 0.8408
# Epoch 37/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4269 - accuracy: 0.8293 - val_loss: 0.4020 - val_accuracy: 0.8497
# Epoch 38/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4234 - accuracy: 0.8321 - val_loss: 0.4187 - val_accuracy: 0.8388
# Epoch 39/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4205 - accuracy: 0.8336 - val_loss: 0.4019 - val_accuracy: 0.8502
# Epoch 40/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4155 - accuracy: 0.8351 - val_loss: 0.4166 - val_accuracy: 0.8454
# Epoch 41/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4217 - accuracy: 0.8358 - val_loss: 0.4126 - val_accuracy: 0.8435
# Epoch 42/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4120 - accuracy: 0.8394 - val_loss: 0.4143 - val_accuracy: 0.8456
# Epoch 43/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4121 - accuracy: 0.8387 - val_loss: 0.4058 - val_accuracy: 0.8500
# Epoch 44/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4098 - accuracy: 0.8393 - val_loss: 0.4169 - val_accuracy: 0.8391
# Epoch 45/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4126 - accuracy: 0.8389 - val_loss: 0.3929 - val_accuracy: 0.8565
# Epoch 46/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4077 - accuracy: 0.8395 - val_loss: 0.3939 - val_accuracy: 0.8522
# Epoch 47/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4048 - accuracy: 0.8414 - val_loss: 0.4007 - val_accuracy: 0.8468
# Epoch 48/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4050 - accuracy: 0.8408 - val_loss: 0.4019 - val_accuracy: 0.8497
# Epoch 49/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4034 - accuracy: 0.8419 - val_loss: 0.4198 - val_accuracy: 0.8396
# Epoch 50/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4019 - accuracy: 0.8428 - val_loss: 0.4267 - val_accuracy: 0.8406
# Epoch 51/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.3996 - accuracy: 0.8455 - val_loss: 0.4190 - val_accuracy: 0.8443
# Epoch 52/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.4007 - accuracy: 0.8435 - val_loss: 0.4004 - val_accuracy: 0.8492
# Epoch 53/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.3518 - accuracy: 0.8660 - val_loss: 0.3707 - val_accuracy: 0.8617
# Epoch 54/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.3304 - accuracy: 0.8724 - val_loss: 0.3702 - val_accuracy: 0.8641
# Epoch 55/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.3208 - accuracy: 0.8775 - val_loss: 0.3693 - val_accuracy: 0.8654
# Epoch 56/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.3185 - accuracy: 0.8781 - val_loss: 0.3693 - val_accuracy: 0.8655
# Epoch 57/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.3113 - accuracy: 0.8816 - val_loss: 0.3640 - val_accuracy: 0.8675
# Epoch 58/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.3038 - accuracy: 0.8833 - val_loss: 0.3629 - val_accuracy: 0.8690
# Epoch 59/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2988 - accuracy: 0.8859 - val_loss: 0.3691 - val_accuracy: 0.8677
# Epoch 60/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2966 - accuracy: 0.8852 - val_loss: 0.3668 - val_accuracy: 0.8691
# Epoch 61/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2950 - accuracy: 0.8859 - val_loss: 0.3649 - val_accuracy: 0.8695
# Epoch 62/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2899 - accuracy: 0.8884 - val_loss: 0.3730 - val_accuracy: 0.8675
# Epoch 63/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2884 - accuracy: 0.8897 - val_loss: 0.3673 - val_accuracy: 0.8680
# Epoch 64/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2866 - accuracy: 0.8889 - val_loss: 0.3639 - val_accuracy: 0.8688
# Epoch 65/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2819 - accuracy: 0.8915 - val_loss: 0.3678 - val_accuracy: 0.8685
# Epoch 66/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2719 - accuracy: 0.8958 - val_loss: 0.3633 - val_accuracy: 0.8724
# Epoch 67/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2683 - accuracy: 0.8974 - val_loss: 0.3630 - val_accuracy: 0.8717
# Epoch 68/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2645 - accuracy: 0.8991 - val_loss: 0.3642 - val_accuracy: 0.8727
# Epoch 69/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2650 - accuracy: 0.8972 - val_loss: 0.3621 - val_accuracy: 0.8735
# Epoch 70/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2649 - accuracy: 0.8976 - val_loss: 0.3660 - val_accuracy: 0.8712
# Epoch 71/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2641 - accuracy: 0.9002 - val_loss: 0.3634 - val_accuracy: 0.8731
# Epoch 72/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2636 - accuracy: 0.8983 - val_loss: 0.3628 - val_accuracy: 0.8741
# Epoch 73/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2618 - accuracy: 0.8994 - val_loss: 0.3646 - val_accuracy: 0.8728
# Epoch 74/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2633 - accuracy: 0.8988 - val_loss: 0.3610 - val_accuracy: 0.8740
# Epoch 75/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2620 - accuracy: 0.9004 - val_loss: 0.3659 - val_accuracy: 0.8728
# Epoch 76/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2608 - accuracy: 0.9004 - val_loss: 0.3640 - val_accuracy: 0.8725
# Epoch 77/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2587 - accuracy: 0.9008 - val_loss: 0.3646 - val_accuracy: 0.8740
# Epoch 78/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2578 - accuracy: 0.9017 - val_loss: 0.3635 - val_accuracy: 0.8739
# Epoch 79/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2572 - accuracy: 0.9011 - val_loss: 0.3633 - val_accuracy: 0.8738
# Epoch 80/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2539 - accuracy: 0.9030 - val_loss: 0.3633 - val_accuracy: 0.8729
# Epoch 81/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2584 - accuracy: 0.9014 - val_loss: 0.3611 - val_accuracy: 0.8751
# Epoch 82/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2570 - accuracy: 0.9019 - val_loss: 0.3626 - val_accuracy: 0.8744
# Epoch 83/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2563 - accuracy: 0.9027 - val_loss: 0.3628 - val_accuracy: 0.8752
# Epoch 84/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2517 - accuracy: 0.9039 - val_loss: 0.3632 - val_accuracy: 0.8733
# Epoch 85/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2562 - accuracy: 0.9036 - val_loss: 0.3628 - val_accuracy: 0.8748
# Epoch 86/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2539 - accuracy: 0.9020 - val_loss: 0.3631 - val_accuracy: 0.8743
# Epoch 87/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2536 - accuracy: 0.9042 - val_loss: 0.3624 - val_accuracy: 0.8735
# Epoch 88/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2521 - accuracy: 0.9041 - val_loss: 0.3631 - val_accuracy: 0.8742
# Epoch 89/100
# 1743/1743 [==============================] - 11s 6ms/step - loss: 0.2559 - accuracy: 0.9020 - val_loss: 0.3626 - val_accuracy: 0.8740
#
# Test Accuracy: 87.40%
# Test Loss: 0.3610
# WARNING:tensorflow:From c:\Users\Microsoft\.conda\envs\gpu_env\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From c:\Users\Microsoft\.conda\envs\gpu_env\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: alzheimer_eeg_model\assets

# %%
# Save model
model.save('alzheimer_eeg_model')
# Out:
# INFO:tensorflow:Assets written to: alzheimer_eeg_model\assets

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Create a figure with two subplots side-by-side
    plt.figure(figsize=(12, 5))
    
    # -----------------------------
    # Plot Model Loss
    # -----------------------------
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    # -----------------------------
    # Plot Model Accuracy
    # -----------------------------
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    # Display the plots
    plt.show()

# Call the function to plot the training history
plot_training_history(history)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 19, 5, 1)]   0
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 19, 5, 2)     20          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 19, 5, 32)    96          depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 19, 5, 32)    128         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 19, 5, 64)    10304       batch_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 64)           0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           1040        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           1088        dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 19, 5, 64)    0           conv2d_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 9, 2, 64)     0           multiply[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d (SpatialDropo (None, 9, 2, 64)     0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 2, 128)    73856       spatial_dropout2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 9, 2, 128)    512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2304)         0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           147520      flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3)            195         dropout[0][0]
# ==================================================================================================
# Total params: 234,759
# Trainable params: 234,439
# Non-trainable params: 320
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

# Generate and save a diagram of the model architecture
plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Obtain predictions from the model on the test set
y_pred_prob = model.predict(X_test)
# For multi-class classification using softmax loss, take the argmax.
y_pred = np.argmax(y_pred_prob, axis=1)

# If you are doing binary classification and using a single output neuron with sigmoid:
# y_pred = (y_pred_prob > 0.5).astype(int).reshape(-1)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Optionally, print the confusion matrix
print("Confusion Matrix:")
print(cm)

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[4907  429  388]
#  [ 246 2941  148]
#  [ 335  210 4338]]

# %%
import seaborn as sns

# Take the first epoch's relative band power (shape: (n_channels, n_bands))
rbp_example = rbp_relative[464, :, :]
plt.figure(figsize=(8, 6))
sns.heatmap(rbp_example, annot=True, cmap='viridis', cbar=True)
plt.title("Relative Band Power Features for Epoch 1")
plt.xlabel("Frequency Bands (order: delta, theta, alpha, beta, gamma)")
plt.ylabel("EEG Channels")
plt.show()
